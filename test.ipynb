# %%
import requests

url = "https://swabhahsa-trigram-endpoint.onrender.com/translate"
data = {
    "sentence": "mama sinhala katakaranne"
}

response = requests.post(url, json=data)
result = response.json()
print(result)
# Out:
# {'detail': "Translation error: Not a gzipped file (b'<!')"}
